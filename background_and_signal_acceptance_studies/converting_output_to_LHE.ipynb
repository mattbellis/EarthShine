# %%
import numpy as np
import pandas as pd

# %%
infilename = 'data//combined/dm_model=core/mA=0p22/mDM=10-90/depth=m100-m8_diskR=100/combined-a070742a-20260710T031433p10794421f1.parquet'

df = pd.read_parquet(infilename)

df

# %%
df.columns

# %%
cols = ['px1', 'py1', 'pz1', 'e1', 'px2', 'py2', 'pz2', 'e2', 'x0', 'y0', 'z0']

df[cols]
